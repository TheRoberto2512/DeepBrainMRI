# %% [markdown]
# <a href="https://colab.research.google.com/github/TheRoberto2512/DeepBrainMRI/blob/main/Modello_EfficientNetV2S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font size=6>**SOMMARIO DEL NOTEBOOK**</font>
#
# In questo notebook andiamo si testa l'efficacia del modello pre-addestrato EfficientNetV2S, fornito direttamente da Keras. Si proverà prima la sua versione base estendendolo con i livelli Dense di classificazione, poi si applicherà il Fine Tuning scongelando gli ultimi livelli per ottimizzare ulteriormente le performance.
#
# Infine, è disponibile un modulo per visualizzare le heatmaps in modo da poter apprezzare le regioni dell'immagine che influenzano la decisione del modello.
#
# Per maggiori informazioni riguardo le scelte intraprese fare riferimento al report finale.
#
#
# **Indice:**
# *   [Installazioni, import librerie e funzioni utili](#1)
# *   [Caricamento del Dataset](#2)
# *   [Modello EfficientNetV2S](#3)
# *   [Modello EfficientNetV2S + Fine Tuning](#4)
# *   [Risultati dell'addestramento](#5)
# *   [Modello Finale](#6)
# *   [Visualizzazione Heatmaps](#7)

# %% [markdown]
# <a name="1"></a>
# # Installazioni, import librerie e funzioni utili

# %%
! pip install tensorflow-gpu==2.8.3

# %%
from sklearn.metrics import confusion_matrix                                      # per la matrice di confusione
from google.colab import drive, files
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import tensorflow as tf
import pandas as pd                                                               # per gestire la serializzazione/deserializzazione dei risultati
import numpy as np                                                                # per gestire gli ndarray con le feature maps
import shutil                                                                     # per fare spostamenti e copie tra drive e colab
import os                                                                         # per gestire le cartelle dei dataset

# %%
drive.mount("/content/drive", force_remount=True)                                 # montiamo il drive per prelevare i dataset

# %% [markdown]
# Qualora la cartella principale del progetto non si trovi nella home di Google Drive, personalizzare la seguente stringa:

# %%
#@title Qualora la cartella principale del progetto non si trovi nella home di Google Drive, personalizzare la seguente stringa:

main_folder_path = '/content/drive/MyDrive/DeepBrainMRI' #@param {type:"string"}

# %% [markdown]
# Le seguenti funzioni servono per salvare/caricare facilmente le history, le evaluation e i pesi del modello su Google Drive.

# %%
result_folder_path = f"{main_folder_path}/Risultati vari/EfficientNetV2S"
saved_weights_path = f"{main_folder_path}/Saved Weights/EfficientNetV2S"
dataset_directory = ''

def saveHistory(history, nomeFile):                                               # funzione per salvare la history di un addestramento
  if not os.path.exists(result_folder_path):
     os.makedirs(result_folder_path)
  history_df = pd.DataFrame.from_dict(history.history)
  history_df.to_csv(result_folder_path + f"/{dataset_directory}_{nomeFile}_history.csv", index=False)

def loadHistory(nomeFile):                                                        # funzione per caricare la history di un addestramento
  if os.path.exists(result_folder_path):
    return pd.read_csv(f"{result_folder_path}/{dataset_directory}_{nomeFile}_history.csv").to_dict()
  else:
    raise Exception("Cartella inesistente!")

def saveEvaluation(loss, acc, f1, nomeFile):                                      # funzione per salvare il risultato di un evaluation
  if not os.path.exists(result_folder_path):
     os.makedirs(result_folder_path)
  evaluation = {}
  evaluation['loss'] = loss
  evaluation['accuracy'] = acc
  evaluation['f1_score'] = f1
  evaluation_df = pd.DataFrame.from_dict(evaluation)
  evaluation_df.to_csv(result_folder_path + f"/{dataset_directory}_{nomeFile}_evaluation.csv", index=False)

def loadEvaluation(nomeFile):                                                     # funzione per caricare il risultato di un evaluation
  if os.path.exists(result_folder_path):
    return pd.read_csv(f"{result_folder_path}/{dataset_directory}_{nomeFile}_evaluation.csv").to_dict()
  else:
    raise Exception("Cartella inesistente!")

def saveWeights(nomeFile):                                                        # funzione per salvare il file dei pesi su drive
  if not os.path.exists(saved_weights_path):
    os.makedirs(saved_weights_path)
  shutil.copy(nomeFile, f"{saved_weights_path}")

def loadWeights(nomeFile):                                                        # funzione per caricare il file dei pesi da drive
  if os.path.exists(saved_weights_path):
    shutil.copy(f"{saved_weights_path}/{nomeFile}", '/content/')
  else:
    raise Exception("Cartella inesistente!")

# %% [markdown]
# <a name="2"></a>
# # Caricamento del dataset

# %% [markdown]
# Impostiamo dei valori costanti per la corretta esecuzione del notebook.

# %%
#@title Impostiamo dei valori costanti per la corretta esecuzione del notebook.
base_datasets_path = f"{main_folder_path}/Datasets/"

BATCH_SIZE = 32 #@param {type: "integer"}                       # specifichiamo la grandezza dei batch
IMAGE_WIDTH = 299 #@param {type: "integer"}
IMAGE_HEIGHT = 299 #@param {type: "integer"}

IMAGE_SHAPE = (IMAGE_WIDTH, IMAGE_HEIGHT, 3)                    # 3 canali perché dev'essere RGB

SEED = 2680 #@param {type: "integer"}                           # seme per poter replicare le stesse condizioni del dataset

# %% [markdown]
# Sceliere il tipo di dataset (train_data) che si vuole importare:

# %%
dataset_directory = 'under+aug'                                 # dataset con undersampling e data augmentation

# %%
dataset_directory = 'only_under'                                # dataset con SOLO undersampling

# %%
dataset_directory = 'only_aug'                                  # dataset con solo data augmentation

# %%
dataset_directory = 'base'                                      # dataset base (già ridimensionato)

# %% [markdown]
# Istruzioni per importare il dataset. **Sono richiesti fino a 2-3 minuti a seconda del dataset.**

# %%
destinazione = f"/content/dataset/{dataset_directory}"

if dataset_directory != 'base':
  shutil.copytree(f'{base_datasets_path}{dataset_directory}', f'{destinazione}/Training', dirs_exist_ok=True)     # train_data pre-processato
else:
  shutil.copytree(f'{base_datasets_path}DATASET_BASE/Training', f'{destinazione}/Training', dirs_exist_ok=True)   # train_data base
print(f"Ho importato il training set \'{dataset_directory}\' nella cartella {destinazione}/Training")

shutil.copytree(f'{base_datasets_path}DATASET_BASE/Testing', f'{destinazione}/Testing', dirs_exist_ok=True)       # importa il test_data
print(f"Ho importato il test set nella cartella {destinazione}/Testing")
# Out:
# Ho importato il training set 'base' nella cartella /content/dataset/base/Training
# Ho importato il test set nella cartella /content/dataset/base/Testing

# %%
train_data = tf.keras.utils.image_dataset_from_directory(
    directory = f'{destinazione}/Training',
    labels='inferred',
    label_mode='categorical',
    color_mode='rgb',
    image_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    batch_size = BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    crop_to_aspect_ratio=True,
)

test_data = tf.keras.utils.image_dataset_from_directory(
    directory = f'{destinazione}/Testing',
    labels='inferred',
    label_mode='categorical',
    color_mode='rgb',
    image_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    batch_size = BATCH_SIZE,
    shuffle=True,
    seed=SEED,
    crop_to_aspect_ratio=True,
)

class_names = test_data.class_names
print("\nHo caricato train_data e test_data dalla cartella %s" % destinazione)
# Out:
# Found 5712 files belonging to 4 classes.
# Found 1311 files belonging to 4 classes.
#
# Ho caricato train_data e test_data dalla cartella /content/dataset/base

# %% [markdown]
# Stampando la shape di un batch di immagini possiamo notare che corrisponderà a:
#
# (**BATCH_SIZE**, **IMAGE_WIDTH**, **IMAGE_HEIGHT**, **3**)

# %%
for img, lbl in train_data.take(1):
  print(img.shape)
# Out:
# (32, 299, 299, 3)

# %% [markdown]
# <a name="3"></a>
# # Modello convolutivo pre-addestrato: EfficientNetV2S

# %%
conv_base = tf.keras.applications.EfficientNetV2S(
    weights="imagenet",
    include_top=False,
    input_shape=IMAGE_SHAPE,
    pooling = 'max', # più adatto al nostro tipo di problema, per prendere le caratteristiche più importanti dell'input
    include_preprocessing=True
)

# %%
conv_base.summary()
# Out:
# Model: "efficientnetv2-s"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  rescaling_1 (Rescaling)     (None, 299, 299, 3)          0         ['input_4[0][0]']
#
#  stem_conv (Conv2D)          (None, 150, 150, 24)         648       ['rescaling_1[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 150, 150, 24)         96        ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 150, 150, 24)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 150, 150, 24)         5184      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 150, 150, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 150, 150, 24)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 150, 150, 24)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 150, 150, 24)         5184      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 150, 150, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 150, 150, 24)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 150, 150, 24)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 150, 150, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 96)           20736     ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 75, 75, 48)           4608      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 75, 75, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 75, 75, 192)          82944     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 75, 75, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 75, 75, 48)           9216      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 75, 75, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 75, 75, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 75, 75, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 75, 75, 192)          82944     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 75, 75, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 75, 75, 48)           9216      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 75, 75, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 75, 75, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 75, 75, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 75, 75, 192)          82944     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 75, 75, 192)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 75, 75, 48)           9216      ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 75, 75, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 75, 75, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 75, 75, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 192)          82944     ['block2d_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 38, 38, 64)           12288     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 38, 38, 64)           256       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 38, 38, 256)          147456    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 38, 38, 256)          1024      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 38, 38, 256)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 38, 38, 64)           16384     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 38, 38, 64)           256       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 38, 38, 64)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 38, 38, 64)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 38, 38, 256)          147456    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 38, 38, 256)          1024      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 38, 38, 256)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 38, 38, 64)           16384     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 38, 38, 64)           256       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 38, 38, 64)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 38, 38, 64)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 38, 38, 256)          147456    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 38, 38, 256)          1024      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 38, 38, 256)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 38, 38, 64)           16384     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 38, 38, 64)           256       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 38, 38, 64)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 38, 38, 64)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 38, 38, 256)          16384     ['block3d_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 38, 38, 256)          1024      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 38, 38, 256)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 19, 19, 256)          2304      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 19, 19, 256)          1024      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 19, 19, 256)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 256)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 256)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 16)             4112      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 256)            4352      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 19, 19, 256)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 19, 19, 128)          32768     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 19, 19, 512)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 19, 19, 512)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 512)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 19, 19, 128)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 19, 19, 128)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 19, 19, 512)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 19, 19, 512)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 512)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 19, 19, 128)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 19, 19, 128)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 19, 19, 512)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 19, 19, 512)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 512)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 19, 19, 128)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 19, 19, 128)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4d_add[0][0]']
#  D)
#
#  block4e_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4e_expand_conv[0][0]']
#  rmalization)
#
#  block4e_expand_activation   (None, 19, 19, 512)          0         ['block4e_expand_bn[0][0]']
#  (Activation)
#
#  block4e_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4e_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4e_dwconv2[0][0]']
#  tion)
#
#  block4e_activation (Activa  (None, 19, 19, 512)          0         ['block4e_bn[0][0]']
#  tion)
#
#  block4e_se_squeeze (Global  (None, 512)                  0         ['block4e_activation[0][0]']
#  AveragePooling2D)
#
#  block4e_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4e_se_squeeze[0][0]']
#  e)
#
#  block4e_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4e_activation[0][0]',
#  y)                                                                  'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4e_se_excite[0][0]']
#  2D)
#
#  block4e_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4e_project_conv[0][0]']
#  ormalization)
#
#  block4e_drop (Dropout)      (None, 19, 19, 128)          0         ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)           (None, 19, 19, 128)          0         ['block4e_drop[0][0]',
#                                                                      'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4e_add[0][0]']
#  D)
#
#  block4f_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4f_expand_conv[0][0]']
#  rmalization)
#
#  block4f_expand_activation   (None, 19, 19, 512)          0         ['block4f_expand_bn[0][0]']
#  (Activation)
#
#  block4f_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4f_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4f_dwconv2[0][0]']
#  tion)
#
#  block4f_activation (Activa  (None, 19, 19, 512)          0         ['block4f_bn[0][0]']
#  tion)
#
#  block4f_se_squeeze (Global  (None, 512)                  0         ['block4f_activation[0][0]']
#  AveragePooling2D)
#
#  block4f_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4f_se_squeeze[0][0]']
#  e)
#
#  block4f_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4f_activation[0][0]',
#  y)                                                                  'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4f_se_excite[0][0]']
#  2D)
#
#  block4f_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4f_project_conv[0][0]']
#  ormalization)
#
#  block4f_drop (Dropout)      (None, 19, 19, 128)          0         ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)           (None, 19, 19, 128)          0         ['block4f_drop[0][0]',
#                                                                      'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 19, 19, 768)          98304     ['block4f_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 19, 19, 768)          3072      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 19, 19, 768)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 19, 19, 768)          6912      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 19, 19, 768)          3072      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 19, 19, 768)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 768)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 32)             24608     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 768)            25344     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 19, 19, 768)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 19, 19, 160)          122880    ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 19, 19, 160)          640       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 19, 19, 960)          153600    ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 19, 19, 960)          3840      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 19, 19, 960)          0         ['block5b_expand_bn[0][0]']
# ...
#  block6l_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6l_se_squeeze[0][0]']
#  e)
#
#  block6l_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multipl  (None, 10, 10, 1536)         0         ['block6l_activation[0][0]',
#  y)                                                                  'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv  (None, 10, 10, 256)          393216    ['block6l_se_excite[0][0]']
#  2D)
#
#  block6l_project_bn (BatchN  (None, 10, 10, 256)          1024      ['block6l_project_conv[0][0]']
#  ormalization)
#
#  block6l_drop (Dropout)      (None, 10, 10, 256)          0         ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)           (None, 10, 10, 256)          0         ['block6l_drop[0][0]',
#                                                                      'block6k_add[0][0]']
#
#  block6m_expand_conv (Conv2  (None, 10, 10, 1536)         393216    ['block6l_add[0][0]']
#  D)
#
#  block6m_expand_bn (BatchNo  (None, 10, 10, 1536)         6144      ['block6m_expand_conv[0][0]']
#  rmalization)
#
#  block6m_expand_activation   (None, 10, 10, 1536)         0         ['block6m_expand_bn[0][0]']
#  (Activation)
#
#  block6m_dwconv2 (Depthwise  (None, 10, 10, 1536)         13824     ['block6m_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6m_bn (BatchNormaliza  (None, 10, 10, 1536)         6144      ['block6m_dwconv2[0][0]']
#  tion)
#
#  block6m_activation (Activa  (None, 10, 10, 1536)         0         ['block6m_bn[0][0]']
#  tion)
#
#  block6m_se_squeeze (Global  (None, 1536)                 0         ['block6m_activation[0][0]']
#  AveragePooling2D)
#
#  block6m_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6m_se_squeeze[0][0]']
#  e)
#
#  block6m_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multipl  (None, 10, 10, 1536)         0         ['block6m_activation[0][0]',
#  y)                                                                  'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv  (None, 10, 10, 256)          393216    ['block6m_se_excite[0][0]']
#  2D)
#
#  block6m_project_bn (BatchN  (None, 10, 10, 256)          1024      ['block6m_project_conv[0][0]']
#  ormalization)
#
#  block6m_drop (Dropout)      (None, 10, 10, 256)          0         ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)           (None, 10, 10, 256)          0         ['block6m_drop[0][0]',
#                                                                      'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2  (None, 10, 10, 1536)         393216    ['block6m_add[0][0]']
#  D)
#
#  block6n_expand_bn (BatchNo  (None, 10, 10, 1536)         6144      ['block6n_expand_conv[0][0]']
#  rmalization)
#
#  block6n_expand_activation   (None, 10, 10, 1536)         0         ['block6n_expand_bn[0][0]']
#  (Activation)
#
#  block6n_dwconv2 (Depthwise  (None, 10, 10, 1536)         13824     ['block6n_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6n_bn (BatchNormaliza  (None, 10, 10, 1536)         6144      ['block6n_dwconv2[0][0]']
#  tion)
#
#  block6n_activation (Activa  (None, 10, 10, 1536)         0         ['block6n_bn[0][0]']
#  tion)
#
#  block6n_se_squeeze (Global  (None, 1536)                 0         ['block6n_activation[0][0]']
#  AveragePooling2D)
#
#  block6n_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6n_se_squeeze[0][0]']
#  e)
#
#  block6n_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multipl  (None, 10, 10, 1536)         0         ['block6n_activation[0][0]',
#  y)                                                                  'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv  (None, 10, 10, 256)          393216    ['block6n_se_excite[0][0]']
#  2D)
#
#  block6n_project_bn (BatchN  (None, 10, 10, 256)          1024      ['block6n_project_conv[0][0]']
#  ormalization)
#
#  block6n_drop (Dropout)      (None, 10, 10, 256)          0         ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)           (None, 10, 10, 256)          0         ['block6n_drop[0][0]',
#                                                                      'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2  (None, 10, 10, 1536)         393216    ['block6n_add[0][0]']
#  D)
#
#  block6o_expand_bn (BatchNo  (None, 10, 10, 1536)         6144      ['block6o_expand_conv[0][0]']
#  rmalization)
#
#  block6o_expand_activation   (None, 10, 10, 1536)         0         ['block6o_expand_bn[0][0]']
#  (Activation)
#
#  block6o_dwconv2 (Depthwise  (None, 10, 10, 1536)         13824     ['block6o_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6o_bn (BatchNormaliza  (None, 10, 10, 1536)         6144      ['block6o_dwconv2[0][0]']
#  tion)
#
#  block6o_activation (Activa  (None, 10, 10, 1536)         0         ['block6o_bn[0][0]']
#  tion)
#
#  block6o_se_squeeze (Global  (None, 1536)                 0         ['block6o_activation[0][0]']
#  AveragePooling2D)
#
#  block6o_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6o_se_squeeze[0][0]']
#  e)
#
#  block6o_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multipl  (None, 10, 10, 1536)         0         ['block6o_activation[0][0]',
#  y)                                                                  'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv  (None, 10, 10, 256)          393216    ['block6o_se_excite[0][0]']
#  2D)
#
#  block6o_project_bn (BatchN  (None, 10, 10, 256)          1024      ['block6o_project_conv[0][0]']
#  ormalization)
#
#  block6o_drop (Dropout)      (None, 10, 10, 256)          0         ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)           (None, 10, 10, 256)          0         ['block6o_drop[0][0]',
#                                                                      'block6n_add[0][0]']
#
#  top_conv (Conv2D)           (None, 10, 10, 1280)         327680    ['block6o_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 10, 10, 1280)         5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 10, 10, 1280)         0         ['top_bn[0][0]']
#  )
#
#  max_pool (GlobalMaxPooling  (None, 1280)                 0         ['top_activation[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 20331360 (77.56 MB)
# Trainable params: 20177488 (76.97 MB)
# Non-trainable params: 153872 (601.06 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Estraiamo le feature maps in modo da poter allenare i layer dense direttamente su queste.

# %%
def get_features_and_labels(dataset):
 all_features, all_labels = [], []

 for images, labels in dataset:
  features = conv_base.predict(images, verbose=0)                                # estrae le feature maps
  all_features.append(features)                                                  # le salviamo in una lista
  all_labels.append(labels)

 return np.concatenate(all_features), np.concatenate(all_labels)

# %% [markdown]
# Eseguiamo il pre-processing per il training set e per il test set.

# %%
train_features, train_labels = get_features_and_labels(train_data)
test_features, test_labels = get_features_and_labels(test_data)

# %% [markdown]
# Ricaviamo una piccola parte (20%) dal training set per usarla come validation set.

# %%
samples = len(train_features)
samples *= 0.2
samples= int(samples)

val_features = train_features[:samples]
train_features = train_features[samples:]

val_labels = train_labels[:samples]
train_labels = train_labels[samples:]

# %% [markdown]
# Costruiamo il modello.

# %%
inputs = tf.keras.Input(shape=(1280))                                            # l'input shape sarà uguale alla shape dell'output dell'ultimo livello dell'EfficientNetV2S

x = tf.keras.layers.Flatten()(inputs)
x = tf.keras.layers.Dropout(rate=0.25)(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)

output = tf.keras.layers.Dense(4, activation='softmax')(x)

model = tf.keras.Model(inputs, output)                                           # crea il modello

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    0.002,                                                                       # learning rate iniziale
    decay_steps=len(train_data)*25,                                              # ogni quanto si decrementa il learning rate
    decay_rate=0.5,                                                              # tasso di decremento
    staircase=True)                                                              # decrementa a intervalli discreti

# %%
model.compile(loss='kullback_leibler_divergence', optimizer=tf.keras.optimizers.Adamax(learning_rate=lr_schedule), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.F1Score()]) # Compila il modello

# %%
model.summary() # riassunto del modello
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1280)]            0
#
#  flatten_1 (Flatten)         (None, 1280)              0
#
#  dropout_2 (Dropout)         (None, 1280)              0
#
#  dense_2 (Dense)             (None, 128)               163968
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 164484 (642.52 KB)
# Trainable params: 164484 (642.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath="EfficientNetV2S.keras", save_best_only=True, monitor="val_loss")  # salviamo i pesi dell'epoca con la val_loss minore
]

# %%
EPOCHE = 50

history = model.fit(train_features, train_labels, epochs=EPOCHE, validation_data=(val_features, val_labels), callbacks=callbacks)
# Out:
# Epoch 1/50
# 160/160 [==============================] - 2s 7ms/step - loss: 1.1780 - accuracy: 0.4657 - precision_10: 0.7724 - recall_10: 0.1842 - f1_score: 0.4452 - val_loss: 0.9544 - val_accuracy: 0.5603 - val_precision_10: 0.9049 - val_recall_10: 0.2163 - val_f1_score: 0.5578
# Epoch 2/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.7984 - accuracy: 0.6712 - precision_10: 0.7837 - recall_10: 0.5112 - f1_score: 0.6716 - val_loss: 0.5549 - val_accuracy: 0.7962 - val_precision_10: 0.8520 - val_recall_10: 0.7351 - val_f1_score: 0.7882
# Epoch 3/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.6210 - accuracy: 0.7561 - precision_10: 0.7979 - recall_10: 0.7045 - f1_score: 0.7568 - val_loss: 0.4639 - val_accuracy: 0.8346 - val_precision_10: 0.8596 - val_recall_10: 0.7915 - val_f1_score: 0.8308
# Epoch 4/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.5360 - accuracy: 0.7868 - precision_10: 0.8181 - recall_10: 0.7527 - f1_score: 0.7870 - val_loss: 0.5104 - val_accuracy: 0.7939 - val_precision_10: 0.8190 - val_recall_10: 0.7586 - val_f1_score: 0.7924
# Epoch 5/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.5006 - accuracy: 0.8051 - precision_10: 0.8297 - recall_10: 0.7749 - f1_score: 0.8055 - val_loss: 0.4449 - val_accuracy: 0.8378 - val_precision_10: 0.8609 - val_recall_10: 0.8150 - val_f1_score: 0.8396
# Epoch 6/50
# 160/160 [==============================] - 1s 9ms/step - loss: 0.4821 - accuracy: 0.8150 - precision_10: 0.8390 - recall_10: 0.7874 - f1_score: 0.8153 - val_loss: 0.3630 - val_accuracy: 0.8895 - val_precision_10: 0.8994 - val_recall_10: 0.8683 - val_f1_score: 0.8894
# Epoch 7/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.4467 - accuracy: 0.8327 - precision_10: 0.8540 - recall_10: 0.8113 - f1_score: 0.8333 - val_loss: 0.3497 - val_accuracy: 0.8840 - val_precision_10: 0.8980 - val_recall_10: 0.8629 - val_f1_score: 0.8819
# Epoch 8/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.4214 - accuracy: 0.8356 - precision_10: 0.8551 - recall_10: 0.8131 - f1_score: 0.8362 - val_loss: 0.3140 - val_accuracy: 0.8981 - val_precision_10: 0.9089 - val_recall_10: 0.8832 - val_f1_score: 0.8972
# Epoch 9/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.4146 - accuracy: 0.8376 - precision_10: 0.8552 - recall_10: 0.8205 - f1_score: 0.8382 - val_loss: 0.3129 - val_accuracy: 0.8981 - val_precision_10: 0.9109 - val_recall_10: 0.8895 - val_f1_score: 0.8980
# Epoch 10/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3960 - accuracy: 0.8489 - precision_10: 0.8643 - recall_10: 0.8311 - f1_score: 0.8495 - val_loss: 0.2946 - val_accuracy: 0.9036 - val_precision_10: 0.9119 - val_recall_10: 0.8926 - val_f1_score: 0.9020
# Epoch 11/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3919 - accuracy: 0.8478 - precision_10: 0.8628 - recall_10: 0.8327 - f1_score: 0.8482 - val_loss: 0.2873 - val_accuracy: 0.9067 - val_precision_10: 0.9147 - val_recall_10: 0.8989 - val_f1_score: 0.9067
# Epoch 12/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3725 - accuracy: 0.8611 - precision_10: 0.8726 - recall_10: 0.8507 - f1_score: 0.8621 - val_loss: 0.2908 - val_accuracy: 0.9028 - val_precision_10: 0.9103 - val_recall_10: 0.8903 - val_f1_score: 0.9007
# Epoch 13/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3823 - accuracy: 0.8568 - precision_10: 0.8694 - recall_10: 0.8437 - f1_score: 0.8568 - val_loss: 0.2659 - val_accuracy: 0.9177 - val_precision_10: 0.9222 - val_recall_10: 0.9099 - val_f1_score: 0.9174
# Epoch 14/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3589 - accuracy: 0.8654 - precision_10: 0.8772 - recall_10: 0.8523 - f1_score: 0.8662 - val_loss: 0.2581 - val_accuracy: 0.9185 - val_precision_10: 0.9230 - val_recall_10: 0.9114 - val_f1_score: 0.9175
# Epoch 15/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.3441 - accuracy: 0.8679 - precision_10: 0.8810 - recall_10: 0.8560 - f1_score: 0.8684 - val_loss: 0.2676 - val_accuracy: 0.9083 - val_precision_10: 0.9170 - val_recall_10: 0.9005 - val_f1_score: 0.9076
# Epoch 16/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3462 - accuracy: 0.8676 - precision_10: 0.8791 - recall_10: 0.8576 - f1_score: 0.8680 - val_loss: 0.2550 - val_accuracy: 0.9138 - val_precision_10: 0.9171 - val_recall_10: 0.9107 - val_f1_score: 0.9137
# Epoch 17/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.3391 - accuracy: 0.8715 - precision_10: 0.8812 - recall_10: 0.8605 - f1_score: 0.8722 - val_loss: 0.2649 - val_accuracy: 0.9154 - val_precision_10: 0.9217 - val_recall_10: 0.9044 - val_f1_score: 0.9158
# Epoch 18/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.3297 - accuracy: 0.8758 - precision_10: 0.8875 - recall_10: 0.8652 - f1_score: 0.8766 - val_loss: 0.2438 - val_accuracy: 0.9263 - val_precision_10: 0.9324 - val_recall_10: 0.9193 - val_f1_score: 0.9254
# Epoch 19/50
# 160/160 [==============================] - 1s 9ms/step - loss: 0.3166 - accuracy: 0.8811 - precision_10: 0.8915 - recall_10: 0.8697 - f1_score: 0.8814 - val_loss: 0.2339 - val_accuracy: 0.9193 - val_precision_10: 0.9225 - val_recall_10: 0.9146 - val_f1_score: 0.9190
# Epoch 20/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3130 - accuracy: 0.8803 - precision_10: 0.8911 - recall_10: 0.8693 - f1_score: 0.8809 - val_loss: 0.2364 - val_accuracy: 0.9208 - val_precision_10: 0.9255 - val_recall_10: 0.9154 - val_f1_score: 0.9213
# Epoch 21/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3093 - accuracy: 0.8819 - precision_10: 0.8924 - recall_10: 0.8730 - f1_score: 0.8826 - val_loss: 0.2331 - val_accuracy: 0.9122 - val_precision_10: 0.9186 - val_recall_10: 0.9114 - val_f1_score: 0.9117
# Epoch 22/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.3112 - accuracy: 0.8783 - precision_10: 0.8871 - recall_10: 0.8666 - f1_score: 0.8790 - val_loss: 0.2309 - val_accuracy: 0.9232 - val_precision_10: 0.9279 - val_recall_10: 0.9185 - val_f1_score: 0.9233
# Epoch 23/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2938 - accuracy: 0.8860 - precision_10: 0.8941 - recall_10: 0.8768 - f1_score: 0.8866 - val_loss: 0.2239 - val_accuracy: 0.9224 - val_precision_10: 0.9266 - val_recall_10: 0.9201 - val_f1_score: 0.9222
# Epoch 24/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2999 - accuracy: 0.8848 - precision_10: 0.8953 - recall_10: 0.8762 - f1_score: 0.8854 - val_loss: 0.2218 - val_accuracy: 0.9279 - val_precision_10: 0.9333 - val_recall_10: 0.9216 - val_f1_score: 0.9270
# Epoch 25/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2773 - accuracy: 0.8932 - precision_10: 0.9034 - recall_10: 0.8834 - f1_score: 0.8934 - val_loss: 0.2195 - val_accuracy: 0.9263 - val_precision_10: 0.9276 - val_recall_10: 0.9240 - val_f1_score: 0.9269
# Epoch 26/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2844 - accuracy: 0.8883 - precision_10: 0.9005 - recall_10: 0.8797 - f1_score: 0.8889 - val_loss: 0.2101 - val_accuracy: 0.9287 - val_precision_10: 0.9327 - val_recall_10: 0.9232 - val_f1_score: 0.9280
# Epoch 27/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2753 - accuracy: 0.8942 - precision_10: 0.9009 - recall_10: 0.8856 - f1_score: 0.8946 - val_loss: 0.1997 - val_accuracy: 0.9318 - val_precision_10: 0.9352 - val_recall_10: 0.9271 - val_f1_score: 0.9311
# Epoch 28/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2651 - accuracy: 0.8977 - precision_10: 0.9058 - recall_10: 0.8893 - f1_score: 0.8984 - val_loss: 0.1954 - val_accuracy: 0.9326 - val_precision_10: 0.9375 - val_recall_10: 0.9295 - val_f1_score: 0.9321
# Epoch 29/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2763 - accuracy: 0.8915 - precision_10: 0.8980 - recall_10: 0.8846 - f1_score: 0.8918 - val_loss: 0.1956 - val_accuracy: 0.9350 - val_precision_10: 0.9389 - val_recall_10: 0.9279 - val_f1_score: 0.9344
# Epoch 30/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2596 - accuracy: 0.8989 - precision_10: 0.9079 - recall_10: 0.8909 - f1_score: 0.8991 - val_loss: 0.1917 - val_accuracy: 0.9303 - val_precision_10: 0.9344 - val_recall_10: 0.9263 - val_f1_score: 0.9296
# Epoch 31/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2555 - accuracy: 0.9018 - precision_10: 0.9105 - recall_10: 0.8944 - f1_score: 0.9022 - val_loss: 0.1901 - val_accuracy: 0.9334 - val_precision_10: 0.9377 - val_recall_10: 0.9318 - val_f1_score: 0.9329
# Epoch 32/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.2428 - accuracy: 0.9058 - precision_10: 0.9101 - recall_10: 0.8987 - f1_score: 0.9061 - val_loss: 0.1914 - val_accuracy: 0.9326 - val_precision_10: 0.9376 - val_recall_10: 0.9303 - val_f1_score: 0.9322
# Epoch 33/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.2394 - accuracy: 0.9083 - precision_10: 0.9136 - recall_10: 0.8997 - f1_score: 0.9086 - val_loss: 0.1788 - val_accuracy: 0.9436 - val_precision_10: 0.9463 - val_recall_10: 0.9389 - val_f1_score: 0.9429
# Epoch 34/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2298 - accuracy: 0.9185 - precision_10: 0.9230 - recall_10: 0.9132 - f1_score: 0.9187 - val_loss: 0.1924 - val_accuracy: 0.9240 - val_precision_10: 0.9268 - val_recall_10: 0.9224 - val_f1_score: 0.9238
# Epoch 35/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2425 - accuracy: 0.9052 - precision_10: 0.9117 - recall_10: 0.8997 - f1_score: 0.9055 - val_loss: 0.1787 - val_accuracy: 0.9350 - val_precision_10: 0.9370 - val_recall_10: 0.9326 - val_f1_score: 0.9349
# Epoch 36/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2222 - accuracy: 0.9120 - precision_10: 0.9186 - recall_10: 0.9062 - f1_score: 0.9122 - val_loss: 0.1885 - val_accuracy: 0.9357 - val_precision_10: 0.9392 - val_recall_10: 0.9326 - val_f1_score: 0.9362
# Epoch 37/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2360 - accuracy: 0.9079 - precision_10: 0.9156 - recall_10: 0.8995 - f1_score: 0.9084 - val_loss: 0.1883 - val_accuracy: 0.9287 - val_precision_10: 0.9308 - val_recall_10: 0.9271 - val_f1_score: 0.9292
# Epoch 38/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2301 - accuracy: 0.9126 - precision_10: 0.9190 - recall_10: 0.9048 - f1_score: 0.9129 - val_loss: 0.1673 - val_accuracy: 0.9373 - val_precision_10: 0.9401 - val_recall_10: 0.9350 - val_f1_score: 0.9371
# Epoch 39/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2325 - accuracy: 0.9107 - precision_10: 0.9182 - recall_10: 0.9060 - f1_score: 0.9110 - val_loss: 0.1761 - val_accuracy: 0.9365 - val_precision_10: 0.9424 - val_recall_10: 0.9357 - val_f1_score: 0.9360
# Epoch 40/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2184 - accuracy: 0.9118 - precision_10: 0.9192 - recall_10: 0.9073 - f1_score: 0.9122 - val_loss: 0.1913 - val_accuracy: 0.9342 - val_precision_10: 0.9367 - val_recall_10: 0.9271 - val_f1_score: 0.9330
# Epoch 41/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2304 - accuracy: 0.9109 - precision_10: 0.9184 - recall_10: 0.9042 - f1_score: 0.9110 - val_loss: 0.1705 - val_accuracy: 0.9381 - val_precision_10: 0.9416 - val_recall_10: 0.9357 - val_f1_score: 0.9378
# Epoch 42/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2228 - accuracy: 0.9165 - precision_10: 0.9254 - recall_10: 0.9112 - f1_score: 0.9168 - val_loss: 0.1679 - val_accuracy: 0.9365 - val_precision_10: 0.9386 - val_recall_10: 0.9342 - val_f1_score: 0.9365
# Epoch 43/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2225 - accuracy: 0.9128 - precision_10: 0.9175 - recall_10: 0.9067 - f1_score: 0.9130 - val_loss: 0.1726 - val_accuracy: 0.9334 - val_precision_10: 0.9355 - val_recall_10: 0.9326 - val_f1_score: 0.9336
# Epoch 44/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2127 - accuracy: 0.9189 - precision_10: 0.9241 - recall_10: 0.9138 - f1_score: 0.9191 - val_loss: 0.1755 - val_accuracy: 0.9326 - val_precision_10: 0.9362 - val_recall_10: 0.9318 - val_f1_score: 0.9326
# Epoch 45/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2236 - accuracy: 0.9091 - precision_10: 0.9156 - recall_10: 0.9052 - f1_score: 0.9093 - val_loss: 0.1702 - val_accuracy: 0.9451 - val_precision_10: 0.9464 - val_recall_10: 0.9404 - val_f1_score: 0.9444
# Epoch 46/50
# 160/160 [==============================] - 1s 7ms/step - loss: 0.2249 - accuracy: 0.9130 - precision_10: 0.9172 - recall_10: 0.9073 - f1_score: 0.9132 - val_loss: 0.1718 - val_accuracy: 0.9397 - val_precision_10: 0.9410 - val_recall_10: 0.9381 - val_f1_score: 0.9397
# Epoch 47/50
# 160/160 [==============================] - 1s 8ms/step - loss: 0.2010 - accuracy: 0.9242 - precision_10: 0.9289 - recall_10: 0.9185 - f1_score: 0.9245 - val_loss: 0.1650 - val_accuracy: 0.9381 - val_precision_10: 0.9386 - val_recall_10: 0.9342 - val_f1_score: 0.9378
# Epoch 48/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2205 - accuracy: 0.9138 - precision_10: 0.9189 - recall_10: 0.9083 - f1_score: 0.9140 - val_loss: 0.1653 - val_accuracy: 0.9412 - val_precision_10: 0.9441 - val_recall_10: 0.9389 - val_f1_score: 0.9409
# Epoch 49/50
# 160/160 [==============================] - 1s 5ms/step - loss: 0.2323 - accuracy: 0.9099 - precision_10: 0.9155 - recall_10: 0.9042 - f1_score: 0.9101 - val_loss: 0.1672 - val_accuracy: 0.9350 - val_precision_10: 0.9385 - val_recall_10: 0.9326 - val_f1_score: 0.9345
# Epoch 50/50
# 160/160 [==============================] - 1s 6ms/step - loss: 0.2153 - accuracy: 0.9203 - precision_10: 0.9255 - recall_10: 0.9146 - f1_score: 0.9204 - val_loss: 0.1637 - val_accuracy: 0.9451 - val_precision_10: 0.9473 - val_recall_10: 0.9436 - val_f1_score: 0.9449

# %% [markdown]
# Per ricaricare i pesi che hanno performato meglio durante l'addestramento:

# %%
model = tf.keras.models.load_model("EfficientNetV2S.keras")

# %% [markdown]
# Se invece si volessero caricare dei pesi da Google Drive:

# %%
print("Inserire il nome del file di salvataggio:")
name = input()
loadWeights(name)
model.load_weights(name)

# %% [markdown]
# Per valutare le performance del modello:

# %%
test_loss, test_accuracy, test_precision, test_recall, test_f1 = model.evaluate(test_features, test_labels)

print(f"Loss: {test_loss}")
print(f"Accuracy: {test_accuracy}")
print(f"Precision: {test_precision}")
print(f"Recall: {test_recall}")
print(f"F1-score: {np.mean(test_f1)}")
# Out:
# 41/41 [==============================] - 0s 3ms/step - loss: 0.2166 - accuracy: 0.9214 - precision_10: 0.9302 - recall_10: 0.9153 - f1_score: 0.9172
# Loss: 0.21655596792697906
# Accuracy: 0.9214340448379517
# Precision: 0.930232584476471
# Recall: 0.9153317809104919
# F1-score: 0.9171687364578247

# %% [markdown]
# ## Salvataggio dei dati

# %% [markdown]
# Per salvare i pesi del modello attuale su Google Drive:

# %%
print("Inserire il nome del file di salvataggio (deve terminare con .keras):")
name = input()
model.save_weights(name)
saveWeights(name)

# %% [markdown]
# Qualora si voglia salvare la history in un file .csv:

# %%
nome = input()
saveHistory(history, nome)

# %% [markdown]
# Qualora si voglia salvare l'evaluation in un file .csv:

# %%
nome = input()
saveEvaluation(test_loss, test_accuracy, test_f1, nome)

# %% [markdown]
# <a name="4"></a>
# # Modello Convolutivo pre-addestrato: EfficientNetV2S + Fine tuning

# %%
conv_base = tf.keras.applications.EfficientNetV2S(
    weights="imagenet",
    include_top=False,  # include_top serve per non includere i layer densamente connessi di classificazione
    input_shape=IMAGE_SHAPE,
    pooling = 'max', # più adatto al nostro tipo di problema, per prendere le caratteristiche più importanti dell'input
    include_preprocessing=True
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 [==============================] - 1s 0us/step

# %%
# di default, tutti i pesi addestrabili sono già tutti scongelati
for layer in conv_base.layers[:-49]:
 layer.trainable = False

# %%
conv_base.summary()
# Out:
# Model: "efficientnetv2-s"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  rescaling (Rescaling)       (None, 299, 299, 3)          0         ['input_1[0][0]']
#
#  stem_conv (Conv2D)          (None, 150, 150, 24)         648       ['rescaling[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 150, 150, 24)         96        ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 150, 150, 24)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_project_conv (Conv  (None, 150, 150, 24)         5184      ['stem_activation[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 150, 150, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1a_project_activation  (None, 150, 150, 24)         0         ['block1a_project_bn[0][0]']
#   (Activation)
#
#  block1a_add (Add)           (None, 150, 150, 24)         0         ['block1a_project_activation[0
#                                                                     ][0]',
#                                                                      'stem_activation[0][0]']
#
#  block1b_project_conv (Conv  (None, 150, 150, 24)         5184      ['block1a_add[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 150, 150, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_project_activation  (None, 150, 150, 24)         0         ['block1b_project_bn[0][0]']
#   (Activation)
#
#  block1b_drop (Dropout)      (None, 150, 150, 24)         0         ['block1b_project_activation[0
#                                                                     ][0]']
#
#  block1b_add (Add)           (None, 150, 150, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 75, 75, 96)           20736     ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 75, 75, 96)           384       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 75, 75, 96)           0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_project_conv (Conv  (None, 75, 75, 48)           4608      ['block2a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2a_project_bn (BatchN  (None, 75, 75, 48)           192       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 75, 75, 192)          82944     ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 75, 75, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_project_conv (Conv  (None, 75, 75, 48)           9216      ['block2b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2b_project_bn (BatchN  (None, 75, 75, 48)           192       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 75, 75, 48)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 75, 75, 48)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 75, 75, 192)          82944     ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 75, 75, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_project_conv (Conv  (None, 75, 75, 48)           9216      ['block2c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2c_project_bn (BatchN  (None, 75, 75, 48)           192       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 75, 75, 48)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 75, 75, 48)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 75, 75, 192)          82944     ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 75, 75, 192)          768       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 75, 75, 192)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_project_conv (Conv  (None, 75, 75, 48)           9216      ['block2d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block2d_project_bn (BatchN  (None, 75, 75, 48)           192       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (Dropout)      (None, 75, 75, 48)           0         ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)           (None, 75, 75, 48)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 38, 38, 192)          82944     ['block2d_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 38, 38, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 38, 38, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_project_conv (Conv  (None, 38, 38, 64)           12288     ['block3a_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3a_project_bn (BatchN  (None, 38, 38, 64)           256       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 38, 38, 256)          147456    ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 38, 38, 256)          1024      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 38, 38, 256)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_project_conv (Conv  (None, 38, 38, 64)           16384     ['block3b_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3b_project_bn (BatchN  (None, 38, 38, 64)           256       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 38, 38, 64)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 38, 38, 64)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 38, 38, 256)          147456    ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 38, 38, 256)          1024      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 38, 38, 256)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_project_conv (Conv  (None, 38, 38, 64)           16384     ['block3c_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3c_project_bn (BatchN  (None, 38, 38, 64)           256       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 38, 38, 64)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 38, 38, 64)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 38, 38, 256)          147456    ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 38, 38, 256)          1024      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 38, 38, 256)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_project_conv (Conv  (None, 38, 38, 64)           16384     ['block3d_expand_activation[0]
#  2D)                                                                [0]']
#
#  block3d_project_bn (BatchN  (None, 38, 38, 64)           256       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (Dropout)      (None, 38, 38, 64)           0         ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)           (None, 38, 38, 64)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 38, 38, 256)          16384     ['block3d_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 38, 38, 256)          1024      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 38, 38, 256)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv2 (Depthwise  (None, 19, 19, 256)          2304      ['block4a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4a_bn (BatchNormaliza  (None, 19, 19, 256)          1024      ['block4a_dwconv2[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 19, 19, 256)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 256)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 256)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 16)             4112      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 256)            4352      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 19, 19, 256)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 19, 19, 128)          32768     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 19, 19, 512)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4b_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4b_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4b_dwconv2[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 19, 19, 512)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 512)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 19, 19, 128)          0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 19, 19, 128)          0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 19, 19, 512)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4c_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4c_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4c_dwconv2[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 19, 19, 512)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 512)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 19, 19, 128)          0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 19, 19, 128)          0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 19, 19, 512)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4d_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4d_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4d_dwconv2[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 19, 19, 512)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 512)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4d_se_squeeze[0][0]']
#  e)
#
#  block4d_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4d_activation[0][0]',
#  y)                                                                  'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4d_se_excite[0][0]']
#  2D)
#
#  block4d_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4d_project_conv[0][0]']
#  ormalization)
#
#  block4d_drop (Dropout)      (None, 19, 19, 128)          0         ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)           (None, 19, 19, 128)          0         ['block4d_drop[0][0]',
#                                                                      'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4d_add[0][0]']
#  D)
#
#  block4e_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4e_expand_conv[0][0]']
#  rmalization)
#
#  block4e_expand_activation   (None, 19, 19, 512)          0         ['block4e_expand_bn[0][0]']
#  (Activation)
#
#  block4e_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4e_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4e_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4e_dwconv2[0][0]']
#  tion)
#
#  block4e_activation (Activa  (None, 19, 19, 512)          0         ['block4e_bn[0][0]']
#  tion)
#
#  block4e_se_squeeze (Global  (None, 512)                  0         ['block4e_activation[0][0]']
#  AveragePooling2D)
#
#  block4e_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4e_se_squeeze[0][0]']
#  e)
#
#  block4e_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4e_activation[0][0]',
#  y)                                                                  'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4e_se_excite[0][0]']
#  2D)
#
#  block4e_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4e_project_conv[0][0]']
#  ormalization)
#
#  block4e_drop (Dropout)      (None, 19, 19, 128)          0         ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)           (None, 19, 19, 128)          0         ['block4e_drop[0][0]',
#                                                                      'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2  (None, 19, 19, 512)          65536     ['block4e_add[0][0]']
#  D)
#
#  block4f_expand_bn (BatchNo  (None, 19, 19, 512)          2048      ['block4f_expand_conv[0][0]']
#  rmalization)
#
#  block4f_expand_activation   (None, 19, 19, 512)          0         ['block4f_expand_bn[0][0]']
#  (Activation)
#
#  block4f_dwconv2 (Depthwise  (None, 19, 19, 512)          4608      ['block4f_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block4f_bn (BatchNormaliza  (None, 19, 19, 512)          2048      ['block4f_dwconv2[0][0]']
#  tion)
#
#  block4f_activation (Activa  (None, 19, 19, 512)          0         ['block4f_bn[0][0]']
#  tion)
#
#  block4f_se_squeeze (Global  (None, 512)                  0         ['block4f_activation[0][0]']
#  AveragePooling2D)
#
#  block4f_se_reshape (Reshap  (None, 1, 1, 512)            0         ['block4f_se_squeeze[0][0]']
#  e)
#
#  block4f_se_reduce (Conv2D)  (None, 1, 1, 32)             16416     ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)  (None, 1, 1, 512)            16896     ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multipl  (None, 19, 19, 512)          0         ['block4f_activation[0][0]',
#  y)                                                                  'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv  (None, 19, 19, 128)          65536     ['block4f_se_excite[0][0]']
#  2D)
#
#  block4f_project_bn (BatchN  (None, 19, 19, 128)          512       ['block4f_project_conv[0][0]']
#  ormalization)
#
#  block4f_drop (Dropout)      (None, 19, 19, 128)          0         ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)           (None, 19, 19, 128)          0         ['block4f_drop[0][0]',
#                                                                      'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2  (None, 19, 19, 768)          98304     ['block4f_add[0][0]']
#  D)
#
#  block5a_expand_bn (BatchNo  (None, 19, 19, 768)          3072      ['block5a_expand_conv[0][0]']
#  rmalization)
#
#  block5a_expand_activation   (None, 19, 19, 768)          0         ['block5a_expand_bn[0][0]']
#  (Activation)
#
#  block5a_dwconv2 (Depthwise  (None, 19, 19, 768)          6912      ['block5a_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block5a_bn (BatchNormaliza  (None, 19, 19, 768)          3072      ['block5a_dwconv2[0][0]']
#  tion)
#
#  block5a_activation (Activa  (None, 19, 19, 768)          0         ['block5a_bn[0][0]']
#  tion)
#
#  block5a_se_squeeze (Global  (None, 768)                  0         ['block5a_activation[0][0]']
#  AveragePooling2D)
#
#  block5a_se_reshape (Reshap  (None, 1, 1, 768)            0         ['block5a_se_squeeze[0][0]']
#  e)
#
#  block5a_se_reduce (Conv2D)  (None, 1, 1, 32)             24608     ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)  (None, 1, 1, 768)            25344     ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multipl  (None, 19, 19, 768)          0         ['block5a_activation[0][0]',
#  y)                                                                  'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv  (None, 19, 19, 160)          122880    ['block5a_se_excite[0][0]']
#  2D)
#
#  block5a_project_bn (BatchN  (None, 19, 19, 160)          640       ['block5a_project_conv[0][0]']
#  ormalization)
#
#  block5b_expand_conv (Conv2  (None, 19, 19, 960)          153600    ['block5a_project_bn[0][0]']
#  D)
#
#  block5b_expand_bn (BatchNo  (None, 19, 19, 960)          3840      ['block5b_expand_conv[0][0]']
#  rmalization)
#
#  block5b_expand_activation   (None, 19, 19, 960)          0         ['block5b_expand_bn[0][0]']
# ...
#  block6l_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6l_se_squeeze[0][0]']
#  e)
#
#  block6l_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multipl  (None, 10, 10, 1536)         0         ['block6l_activation[0][0]',
#  y)                                                                  'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv  (None, 10, 10, 256)          393216    ['block6l_se_excite[0][0]']
#  2D)
#
#  block6l_project_bn (BatchN  (None, 10, 10, 256)          1024      ['block6l_project_conv[0][0]']
#  ormalization)
#
#  block6l_drop (Dropout)      (None, 10, 10, 256)          0         ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)           (None, 10, 10, 256)          0         ['block6l_drop[0][0]',
#                                                                      'block6k_add[0][0]']
#
#  block6m_expand_conv (Conv2  (None, 10, 10, 1536)         393216    ['block6l_add[0][0]']
#  D)
#
#  block6m_expand_bn (BatchNo  (None, 10, 10, 1536)         6144      ['block6m_expand_conv[0][0]']
#  rmalization)
#
#  block6m_expand_activation   (None, 10, 10, 1536)         0         ['block6m_expand_bn[0][0]']
#  (Activation)
#
#  block6m_dwconv2 (Depthwise  (None, 10, 10, 1536)         13824     ['block6m_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6m_bn (BatchNormaliza  (None, 10, 10, 1536)         6144      ['block6m_dwconv2[0][0]']
#  tion)
#
#  block6m_activation (Activa  (None, 10, 10, 1536)         0         ['block6m_bn[0][0]']
#  tion)
#
#  block6m_se_squeeze (Global  (None, 1536)                 0         ['block6m_activation[0][0]']
#  AveragePooling2D)
#
#  block6m_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6m_se_squeeze[0][0]']
#  e)
#
#  block6m_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multipl  (None, 10, 10, 1536)         0         ['block6m_activation[0][0]',
#  y)                                                                  'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv  (None, 10, 10, 256)          393216    ['block6m_se_excite[0][0]']
#  2D)
#
#  block6m_project_bn (BatchN  (None, 10, 10, 256)          1024      ['block6m_project_conv[0][0]']
#  ormalization)
#
#  block6m_drop (Dropout)      (None, 10, 10, 256)          0         ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)           (None, 10, 10, 256)          0         ['block6m_drop[0][0]',
#                                                                      'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2  (None, 10, 10, 1536)         393216    ['block6m_add[0][0]']
#  D)
#
#  block6n_expand_bn (BatchNo  (None, 10, 10, 1536)         6144      ['block6n_expand_conv[0][0]']
#  rmalization)
#
#  block6n_expand_activation   (None, 10, 10, 1536)         0         ['block6n_expand_bn[0][0]']
#  (Activation)
#
#  block6n_dwconv2 (Depthwise  (None, 10, 10, 1536)         13824     ['block6n_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6n_bn (BatchNormaliza  (None, 10, 10, 1536)         6144      ['block6n_dwconv2[0][0]']
#  tion)
#
#  block6n_activation (Activa  (None, 10, 10, 1536)         0         ['block6n_bn[0][0]']
#  tion)
#
#  block6n_se_squeeze (Global  (None, 1536)                 0         ['block6n_activation[0][0]']
#  AveragePooling2D)
#
#  block6n_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6n_se_squeeze[0][0]']
#  e)
#
#  block6n_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multipl  (None, 10, 10, 1536)         0         ['block6n_activation[0][0]',
#  y)                                                                  'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv  (None, 10, 10, 256)          393216    ['block6n_se_excite[0][0]']
#  2D)
#
#  block6n_project_bn (BatchN  (None, 10, 10, 256)          1024      ['block6n_project_conv[0][0]']
#  ormalization)
#
#  block6n_drop (Dropout)      (None, 10, 10, 256)          0         ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)           (None, 10, 10, 256)          0         ['block6n_drop[0][0]',
#                                                                      'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2  (None, 10, 10, 1536)         393216    ['block6n_add[0][0]']
#  D)
#
#  block6o_expand_bn (BatchNo  (None, 10, 10, 1536)         6144      ['block6o_expand_conv[0][0]']
#  rmalization)
#
#  block6o_expand_activation   (None, 10, 10, 1536)         0         ['block6o_expand_bn[0][0]']
#  (Activation)
#
#  block6o_dwconv2 (Depthwise  (None, 10, 10, 1536)         13824     ['block6o_expand_activation[0]
#  Conv2D)                                                            [0]']
#
#  block6o_bn (BatchNormaliza  (None, 10, 10, 1536)         6144      ['block6o_dwconv2[0][0]']
#  tion)
#
#  block6o_activation (Activa  (None, 10, 10, 1536)         0         ['block6o_bn[0][0]']
#  tion)
#
#  block6o_se_squeeze (Global  (None, 1536)                 0         ['block6o_activation[0][0]']
#  AveragePooling2D)
#
#  block6o_se_reshape (Reshap  (None, 1, 1, 1536)           0         ['block6o_se_squeeze[0][0]']
#  e)
#
#  block6o_se_reduce (Conv2D)  (None, 1, 1, 64)             98368     ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)  (None, 1, 1, 1536)           99840     ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multipl  (None, 10, 10, 1536)         0         ['block6o_activation[0][0]',
#  y)                                                                  'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv  (None, 10, 10, 256)          393216    ['block6o_se_excite[0][0]']
#  2D)
#
#  block6o_project_bn (BatchN  (None, 10, 10, 256)          1024      ['block6o_project_conv[0][0]']
#  ormalization)
#
#  block6o_drop (Dropout)      (None, 10, 10, 256)          0         ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)           (None, 10, 10, 256)          0         ['block6o_drop[0][0]',
#                                                                      'block6n_add[0][0]']
#
#  top_conv (Conv2D)           (None, 10, 10, 1280)         327680    ['block6o_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 10, 10, 1280)         5120      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 10, 10, 1280)         0         ['top_bn[0][0]']
#  )
#
#  max_pool (GlobalMaxPooling  (None, 1280)                 0         ['top_activation[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 20331360 (77.56 MB)
# Trainable params: 3345600 (12.76 MB)
# Non-trainable params: 16985760 (64.80 MB)
# __________________________________________________________________________________________________

# %%
inputs = tf.keras.Input(shape=IMAGE_SHAPE)                                       # la shape è stata definita durante l'import del dataset

x = conv_base(inputs)                                                            # estrazione delle feature maps dall'EfficientNetV2S

x = tf.keras.layers.Flatten()(x)                                                 # vettorializziamo perché i Dense manipolano solo tensori a una dimensione
x = tf.keras.layers.Dropout(rate=0.25)(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)

output = tf.keras.layers.Dense(4, activation='softmax')(x)                       # layer di output

model = tf.keras.Model(inputs, output)                                           # crea il modello

# %%
model.summary() # visualizza il riassunto del modello
# Out:
# Model: "model_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 299, 299, 3)]     0
#
#  efficientnetv2-s (Function  (None, 1280)              20331360
#  al)
#
#  flatten_11 (Flatten)        (None, 1280)              0
#
#  dropout_16 (Dropout)        (None, 1280)              0
#
#  dense_28 (Dense)            (None, 128)               163968
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_29 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 20495844 (78.19 MB)
# Trainable params: 3510084 (13.39 MB)
# Non-trainable params: 16985760 (64.80 MB)
# _________________________________________________________________

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath="EfficientNetV2SFT.keras", save_best_only=True, monitor="val_loss"),  # salviamo i pesi dell'epoca con la val_loss minore
]

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    0.002,
    decay_steps=len(train_data)*5,
    decay_rate=0.75,
    staircase=True)

# %%
model.compile(loss='kullback_leibler_divergence', optimizer=tf.keras.optimizers.Adamax(learning_rate= lr_schedule), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.F1Score()]) # Compila il modello

# %%
total_batches = tf.data.experimental.cardinality(train_data).numpy()              # calcola il numero totale di batch nel dataset

validation_size = int(0.2 * total_batches)                                        # imposta una percentuale per il validation set (in questo caso 20%)

# separa i dataset di training e validation
validation_data = train_data.take(validation_size)
train_data = train_data.skip(validation_size)

# %%
EPOCHE = 20

historyFT = model.fit(train_data, epochs=EPOCHE, validation_data=validation_data, callbacks=callbacks)

# %% [markdown]
# Per ricaricare i pesi che hanno performato meglio durante l'addestramento:

# %%
model = tf.keras.models.load_model("EfficientNetV2SFT.keras")

# %% [markdown]
# Se invece si volessero caricare dei pesi da Google Drive:

# %%
print("Inserire il nome del file di salvataggio:")
name = input()
loadWeights(name)
model.load_weights(name)

# %% [markdown]
# Per valutare le performance del modello:

# %%
test_loss, test_accuracy, test_precision, test_recall, test_f1 = model.evaluate(test_data)
print(f"Loss: {test_loss}")
print(f"Accuracy: {test_accuracy}")
print(f"Precision: {test_precision}")
print(f"Recall: {test_recall}")
print(f"F1-score: {np.mean(test_f1)}")
# Out:
# 41/41 [==============================] - 14s 305ms/step - loss: 0.0178 - accuracy: 0.9954 - precision: 0.9962 - recall: 0.9954 - f1_score: 0.9950
# Loss: 0.01784178428351879
# Accuracy: 0.9954233169555664
# Precision: 0.9961832165718079
# Recall: 0.9954233169555664
# F1-score: 0.995043933391571

# %% [markdown]
# ## Salvataggio dei dati

# %% [markdown]
# Per salvare i pesi del modello attuale su Google Drive:

# %%
print("Inserire il nome del file di salvataggio:")
name = input()
model.save_weights(name)
saveWeights(name)

# %% [markdown]
# Qualora si voglia salvare la history in un file .csv:

# %%
nome = input()
saveHistory(history, nome)

# %% [markdown]
# Qualora si voglia salvare l'evaluation in un file .csv:

# %%
nome = input()
saveEvaluation(test_loss, test_accuracy, test_f1, nome)

# %% [markdown]
# <a name="5"></a>
# # Risultati dell'addestramento

# %% [markdown]
# ## History dell'addestramento appena concluso (base)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
f1_score = []
val_f1_score = []

epochs = range(1, len(acc) + 1)

for i in range(len(acc)):
  f1_score.append(np.mean(history.history['f1_score'][i]))
  val_f1_score.append(np.mean(history.history['val_f1_score'][i]))

# %% [markdown]
# ## History dell'addestramento appena concluso (Fine Tuning)

# %%
acc = historyFT.history['accuracy']
val_acc = historyFT.history['val_accuracy']
loss = historyFT.history['loss']
val_loss = historyFT.history['val_loss']
f1_score = []
val_f1_score = []

epochs = range(1, len(acc) + 1)

for i in range(len(acc)):
  f1_score.append(np.mean(historyFT.history['f1_score'][i]))
  val_f1_score.append(np.mean(historyFT.history['val_f1_score'][i]))

# %% [markdown]
# ## History di un addestramento passato (da caricare)

# %% [markdown]
# Per ricaricare una history precedente:

# %%
print("Inserire il nome del file history da caricare:")
nomeFile = input()
history = loadHistory(nomeFile)

# %%
acc, val_acc, loss, val_loss = [], [], [], []
for i in range(0, len(history['accuracy'])):
  acc.append(history['accuracy'][i])
  val_acc.append(history['val_accuracy'][i])
  loss.append(history['loss'][i])
  val_loss.append(history['val_loss'][i])

epochs = range(1, len(acc)+1)

f1_score, val_f1_score = [], []

for i in range(len(acc)):
  f1_score.append(np.mean([float(x) for x in history['f1_score'][i].replace('[', '').replace(']', '').split()]))
  val_f1_score.append(np.mean([float(x) for x in history['val_f1_score'][i].replace('[', '').replace(']', '').split()]))

# %% [markdown]
# ## Plot dei risultati

# %%
# Creazione del grafico per l'accuracy
plt.figure(figsize=(21, 6))
plt.subplot(1, 3, 1)
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Accuracy')

plt.plot(np.argmax((val_acc))+1, np.max(val_acc), 'o', color='#00b050', label='Best Epoch')

plt.legend()
plt.xlim([1, np.max(epochs)])
plt.ylim([0.82, 1])
plt.grid()

# Creazione del grafico per il loss
plt.subplot(1, 3, 2)
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Loss')

plt.plot(np.argmin((val_loss))+1, np.min(val_loss), 'o', color='#00b050', label='Best Epoch')

plt.legend()
plt.xlim([1, np.max(epochs)])
plt.ylim([0, 0.4])
plt.grid()

# Creazione del grafico per l'F1 score
plt.subplot(1, 3, 3)
plt.plot(epochs, f1_score, 'r', label='Training F1 score')
plt.plot(epochs, val_f1_score, 'b', label='Validation F1 score')
plt.title('F1 score')

plt.plot(np.argmax((val_f1_score))+1, np.max(val_f1_score), 'o', color='#00b050', label='Best Epoch')

plt.legend()
plt.xlim([1, np.max(epochs)])
plt.ylim([0.82, 1])
plt.grid()

plt.show()

# %% [markdown]
# <a name="6"></a>
# # Modello Finale

# %% [markdown]
# Una volta valutate i migliori iperparametri per il nostro modello, lo riaddestriamo interamente sul training set senza nessun validation.
# <font color='#c00000'>**ATTENZIONE**:</font> Ricaricare il test data se è stato splittato precedentemente per il validation!

# %%
conv_base = tf.keras.applications.EfficientNetV2S(
    weights="imagenet",
    include_top=False,
    input_shape=IMAGE_SHAPE,
    pooling = 'max',
    include_preprocessing=True
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 [==============================] - 5s 0us/step

# %%
# di default, tutti i pesi addestrabili sono già tutti scongelati
for layer in conv_base.layers[:-49]:
 layer.trainable = False

# %%
conv_base.summary()

# %%
inputs = tf.keras.Input(shape=IMAGE_SHAPE)                                       # la shape è stata definita durante l'import del dataset

x = conv_base(inputs)                                                            # estrazione delle feature maps dall'EfficientNetV2S

x = tf.keras.layers.Flatten()(x)                                                 # vettorializziamo perché i Dense manipolano solo tensori a una dimensione
x = tf.keras.layers.Dropout(rate=0.25)(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dropout(rate=0.25)(x)

output = tf.keras.layers.Dense(4, activation='softmax')(x)                       # layer di output

model = tf.keras.Model(inputs, output)                                           # crea il modello

# %%
model.summary() # visualizza il riassunto del modello

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath="EfficientNetV2SFT.keras", save_best_only=True, monitor="loss"),  # salviamo i pesi dell'epoca con la loss minore
]

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    0.002,
    decay_steps=len(train_data)*5,
    decay_rate=0.75,
    staircase=True)

# %%
model.compile(loss='kullback_leibler_divergence', optimizer=tf.keras.optimizers.Adamax(learning_rate=lr_schedule), metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tf.keras.metrics.F1Score()]) # Compila il modello

# %%
EPOCHE = 20

historyFT = model.fit(train_data, epochs=EPOCHE, callbacks=callbacks)
# Out:
# Epoch 1/20
# 179/179 [==============================] - 77s 290ms/step - loss: 1.6527 - accuracy: 0.7257 - precision: 0.7677 - recall: 0.6786 - f1_score: 0.7048
# Epoch 2/20
# 179/179 [==============================] - 53s 295ms/step - loss: 0.2547 - accuracy: 0.9084 - precision: 0.9184 - recall: 0.8925 - f1_score: 0.9045
# Epoch 3/20
# 179/179 [==============================] - 52s 289ms/step - loss: 0.1578 - accuracy: 0.9417 - precision: 0.9491 - recall: 0.9345 - f1_score: 0.9394
# Epoch 4/20
# 179/179 [==============================] - 54s 299ms/step - loss: 0.1159 - accuracy: 0.9597 - precision: 0.9631 - recall: 0.9559 - f1_score: 0.9579
# Epoch 5/20
# 179/179 [==============================] - 53s 295ms/step - loss: 0.0922 - accuracy: 0.9652 - precision: 0.9676 - recall: 0.9629 - f1_score: 0.9638
# Epoch 6/20
# 179/179 [==============================] - 54s 299ms/step - loss: 0.0686 - accuracy: 0.9762 - precision: 0.9772 - recall: 0.9741 - f1_score: 0.9753
# Epoch 7/20
# 179/179 [==============================] - 54s 298ms/step - loss: 0.0472 - accuracy: 0.9839 - precision: 0.9849 - recall: 0.9828 - f1_score: 0.9832
# Epoch 8/20
# 179/179 [==============================] - 53s 295ms/step - loss: 0.0450 - accuracy: 0.9855 - precision: 0.9863 - recall: 0.9837 - f1_score: 0.9848
# Epoch 9/20
# 179/179 [==============================] - 54s 298ms/step - loss: 0.0430 - accuracy: 0.9849 - precision: 0.9858 - recall: 0.9837 - f1_score: 0.9844
# Epoch 10/20
# 179/179 [==============================] - 53s 296ms/step - loss: 0.0336 - accuracy: 0.9895 - precision: 0.9902 - recall: 0.9890 - f1_score: 0.9892
# Epoch 11/20
# 179/179 [==============================] - 53s 293ms/step - loss: 0.0326 - accuracy: 0.9890 - precision: 0.9897 - recall: 0.9884 - f1_score: 0.9885
# Epoch 12/20
# 179/179 [==============================] - 54s 296ms/step - loss: 0.0272 - accuracy: 0.9928 - precision: 0.9933 - recall: 0.9925 - f1_score: 0.9926
# Epoch 13/20
# 179/179 [==============================] - 55s 299ms/step - loss: 0.0213 - accuracy: 0.9935 - precision: 0.9935 - recall: 0.9935 - f1_score: 0.9933
# Epoch 14/20
# 179/179 [==============================] - 54s 296ms/step - loss: 0.0200 - accuracy: 0.9940 - precision: 0.9944 - recall: 0.9939 - f1_score: 0.9939
# Epoch 15/20
# 179/179 [==============================] - 51s 283ms/step - loss: 0.0263 - accuracy: 0.9911 - precision: 0.9916 - recall: 0.9909 - f1_score: 0.9908
# Epoch 16/20
# 179/179 [==============================] - 53s 294ms/step - loss: 0.0166 - accuracy: 0.9949 - precision: 0.9951 - recall: 0.9949 - f1_score: 0.9947
# Epoch 17/20
# 179/179 [==============================] - 51s 284ms/step - loss: 0.0190 - accuracy: 0.9956 - precision: 0.9956 - recall: 0.9951 - f1_score: 0.9955
# Epoch 18/20
# 179/179 [==============================] - 54s 297ms/step - loss: 0.0153 - accuracy: 0.9949 - precision: 0.9951 - recall: 0.9946 - f1_score: 0.9948
# Epoch 19/20
# 179/179 [==============================] - 53s 292ms/step - loss: 0.0128 - accuracy: 0.9956 - precision: 0.9956 - recall: 0.9953 - f1_score: 0.9954
# Epoch 20/20
# 179/179 [==============================] - 53s 295ms/step - loss: 0.0111 - accuracy: 0.9960 - precision: 0.9961 - recall: 0.9958 - f1_score: 0.9958

# %% [markdown]
# Per ricaricare i pesi che hanno performato meglio durante l'addestramento:

# %%
model = tf.keras.models.load_model("EfficientNetV2SFT.keras")

# %% [markdown]
# Se invece si volessero caricare dei pesi da Google Drive:

# %%
print("Inserire il nome del file di salvataggio:")
name = input()
loadWeights(name)
model.load_weights(name)

# %% [markdown]
# Per valutare le performance del modello:

# %%
test_loss, test_accuracy, test_precision, test_recall, test_f1 = model.evaluate(test_data)
print(f"Loss: {test_loss}")
print(f"Accuracy: {test_accuracy}")
print(f"Precision: {test_precision}")
print(f"Recall: {test_recall}")
print(f"F1-score: {np.mean(test_f1)}")
# Out:
# 41/41 [==============================] - 17s 294ms/step - loss: 0.0178 - accuracy: 0.9954 - precision: 0.9962 - recall: 0.9954 - f1_score: 0.9950
# Loss: 0.017841782420873642
# Accuracy: 0.9954233169555664
# Precision: 0.9961832165718079
# Recall: 0.9954233169555664
# F1-score: 0.995043933391571

# %% [markdown]
# ##Matrice di confusione

# %% [markdown]
# Creazione della matrice di confusione:

# %%
previsioni_classe = []
verita_terreno = []

# Effettuare le previsioni su ogni batch
for immagini, etichette in test_data:
    preds = model.predict(immagini, verbose=0)
    previsioni_classe.extend(np.argmax(preds, axis=1))
    verita_terreno.extend(np.argmax(etichette.numpy(), axis=1))

# Calcolare la matrice di confusione
matrice_confusione = confusion_matrix(verita_terreno, previsioni_classe)

# %% [markdown]
# Creazione del plot della matrice di confusione:

# %%
plt.figure(figsize=(10, 8))
plt.imshow(matrice_confusione, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Matrice di Confusione')
plt.colorbar()

# Aggiungere le etichette agli assi
plt.xticks(np.arange(len(class_names)), class_names, rotation=45)
plt.yticks(np.arange(len(class_names)), class_names)

# Etichettare gli assi
plt.xlabel('Previsioni')
plt.ylabel('Verità Terreno')

# Mostrare i numeri all'interno delle celle
thresh = matrice_confusione.max() / 2.
for i in range(matrice_confusione.shape[0]):
    for j in range(matrice_confusione.shape[1]):
        plt.text(i, j, format(matrice_confusione[i, j], 'd'),
             horizontalalignment="center",
             color="white" if matrice_confusione[i, j] > thresh else "black")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Salvataggio dei dati

# %% [markdown]
# Per salvare i pesi del modello attuale su Google Drive:

# %%
print("Inserire il nome del file di salvataggio (deve terminare con .keras):")
name = input()
model.save_weights(name)
saveWeights(name)

# %% [markdown]
# Qualora si voglia salvare la history in un file .csv:

# %%
nome = input()
saveHistory(historyFT, nome)

# %% [markdown]
# Qualora si voglia salvare l'evaluation in un file .csv:

# %%
nome = input()
saveEvaluation(test_loss, test_accuracy, test_f1, nome)

# %% [markdown]
# <a name="7"></a>
# #Heat Maps

# %% [markdown]
# Prima definiamo una funzione che trasforma l'immagine in un array e lo pre-processa usando la funzione di EfficientNetV2

# %%
def get_img_array(img_path, target_size):
  img = tf.keras.utils.load_img(img_path, target_size=target_size)
  array = tf.keras.utils.img_to_array(img)
  array = np.expand_dims(array, axis=0)
  array = tf.keras.applications.efficientnet_v2.preprocess_input(array)
  return array

# %% [markdown]
# Dobbiamo costruire un modello che mappi le attivazioni dell'ultimo strato convoluzionale con le previsioni finali della classe.

# %%
last_conv_layer_name = "top_activation"                                                   # nome dell'ultimo livello convolutivo (dentro efficientnetv2)

efficientnet_model = model.get_layer('efficientnetv2-s')                                  # estraggo efficientnet dal modello (si parte dal modello con fine tuning)

last_conv_layer = efficientnet_model.get_layer(last_conv_layer_name)                      # estraggo il livello interessato

last_conv_layer_model = tf.keras.Model(efficientnet_model.input, last_conv_layer.output)  # creiamo il modello con l'ultimo livello convolutivo

classifier_input = tf.keras.Input(shape=last_conv_layer.output.shape[1:])

x = classifier_input
x = efficientnet_model.get_layer('max_pool')(x)                                           # estriamo anche l'ultimo livello di pooling da efficientnetv2
x = model.get_layer('flatten')(x)
x = model.get_layer('dropout')(x)
x = model.get_layer('dense')(x)                                                           # costruiamo il modello estraendo anche i Dense di classificazione dal modello col fine tuning
x = model.get_layer('dropout_1')(x)
x = model.get_layer('dense_1')(x)

classifier_model = tf.keras.Model(classifier_input, x)                                    # il modello è pronto

# %% [markdown]
# Inserire il path dell'immagine che si vuole classificare e analizzare:

# %%
# @title Percorso e Heat Map intermedia
img_path = "/content/dataset/base/Testing/meningioma/Te-me_0239.jpg" # @param {type:"string"}
showHeatMaps = True # @param {type:"boolean"}                                   # è possibile scegliere se si vuole visualizzare l'heatmap appena la si estrae

# %% [markdown]
# Si applica la tecnica Grad-CAM per estrarre una HeatMap e vedere quali zone dell'immagine hanno influenzato la decisione del modello.

# %%
with tf.GradientTape() as tape:
  last_conv_layer_output = last_conv_layer_model(get_img_array(img_path, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))) # Calcolare le attivazioni dell'ultimo strato convolutivo
  tape.watch(last_conv_layer_output)                                              # facciamole osservare al tape
                                                                                  # Recuperiamo il canale di attivazione corrispondente alla classe superiore prevista
  preds = classifier_model(last_conv_layer_output)
  top_pred_index = tf.argmax(preds[0])
  top_class_channel = preds[:, top_pred_index]

grads = tape.gradient(top_class_channel, last_conv_layer_output)                  # gradiente della classe maggiormente prevista rispetto alla mappa delle caratteristiche in uscita dall'ultimo strato convoluzionale

pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2)).numpy()                      # vettore in cui ogni voce rappresenta l'intensità media del gradiente per un determinato canale

last_conv_layer_output = last_conv_layer_output.numpy()[0]                        # Quantifica l'importanza di ciascun canale rispetto alla classe superiore prevista
for i in range(pooled_grads.shape[-1]):
  last_conv_layer_output[:, :, i] *= pooled_grads[i]                              # Moltiplica ogni canale nell'output dell'ultimo strato convoluzionale per "l'importanza (peso) di questo canale"
heatmap = np.mean(last_conv_layer_output, axis=-1)

heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)

if showHeatMaps:                                                                  # in base alla variabile valorizzata nella cella prima
  plt.matshow(heatmap)

# %% [markdown]
# Una volta estratta la heatmap la si prepara per poterla sovrapporre all'immagine originale e visualizzarla nel plot.

# %%
img = tf.keras.utils.load_img(img_path, color_mode='grayscale')
img = tf.keras.utils.img_to_array(img)
heatmap = np.uint8(255 * heatmap)
jet = plt.colormaps.get_cmap('jet')                                               # Utilizzare la colormap "jet" per ricolorare la mappa di calore.
jet_colors = jet(np.arange(256))[:, :3]
jet_heatmap = jet_colors[heatmap]
jet_heatmap = tf.keras.utils.array_to_img(jet_heatmap)
jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
jet_heatmap = tf.keras.utils.img_to_array(jet_heatmap)
superimposed_img = jet_heatmap * 0.7 + img                                        # Sovrapponiamo la heatmap all'immagine originale, con il 70% di opacità

superimposed_img = tf.keras.utils.array_to_img(superimposed_img)

fig = plt.figure(figsize=(11, 5))
plt.subplot(1, 2, 1)
img_array = get_img_array(img_path, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT))

plt.axis("off")
plt.imshow(tf.keras.utils.load_img(img_path, target_size=(IMAGE_WIDTH, IMAGE_HEIGHT)))

plt.subplot(1, 2, 2)
plt.imshow(superimposed_img)
plt.axis("off")

fig.text(0.5, 0, f"Secondo il modello questa foto appartiene alla classe \'%s\' (%.2f%%)" % (class_names[np.argmax(preds[0])], np.max(preds[0])*100), ha='center', va='bottom', fontsize='16')

plt.show()

# %%
print("Lista di tutte le probabilità per ogni classe")
for i, prob in enumerate(preds[0]):
        print(f"- %s: \t%.5f%%" % (class_names[i], prob*100))
# Out:
# Lista di tutte le probabilità per ogni classe
# - glioma: 	0.00508%
# - meningioma: 	99.99492%
# - notumor: 	0.00000%
# - pituitary: 	0.00000%

# %% [markdown]
# Download dell'immagine a cui è stata applicata la heatmap:

# %%
print("Inserire il nome dell'immagine per salvarla:")
nome = input()
save_path = f"{nome}.jpg"
superimposed_img.save(save_path)
files.download(save_path)
